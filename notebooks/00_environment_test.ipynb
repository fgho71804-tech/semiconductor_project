# %% [markdown]
# # 00. Environment Test
# 필수 패키지와 프로젝트 경로를 확인합니다.

# %%
from pathlib import Path
import numpy as np
import pandas as pd
import matplotlib
import scipy
import sklearn

project_root = Path.cwd().parent if Path.cwd().name == 'notebooks' else Path.cwd()
print('project_root:', project_root.resolve())
print('pandas:', pd.__version__)
print('numpy:', np.__version__)
print('scikit-learn:', sklearn.__version__)
print('raw data exists:', (project_root / 'data/raw/secom.data').exists())
# Out:
# project_root: C:\Users\user\Desktop\취준\semiconductor_yield_quality_analysis
# pandas: 3.0.3
# numpy: 2.4.6
# scikit-learn: 1.9.0
# raw data exists: True
